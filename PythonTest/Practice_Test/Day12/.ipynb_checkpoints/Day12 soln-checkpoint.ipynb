# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Automobile_data.csv',
#  'DAY-12.docx',
#  'Day12 soln.ipynb']

# %%
import pandas

# %%
df1 = pandas.read_csv("Automobile_data.csv")

# %% [markdown]
# # Question 1: From given data set print first and last five rows.

# %% [markdown]
# # first five rows

# %%
df1.iloc[0:5,:]
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df1.head() #returns first 5 rows by default
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
# 5             five         110               19  15250.0

# %% [markdown]
# # last five rows

# %%
df1.iloc[-5:,:]
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df1.tail() #returns last 5 rows by default
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# # Question 2: Clean data and update the CSV file.

# %% [markdown]
# # Question 3: Find the most expensive car company name.

# %%
df1.price.max()
# Out:
# 45400.0

# %%
df1[["price","company"]]

# %%
df1[["company","price"]][df1.price == df1.price.max()]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# # Question 4: Print All Toyota Cars details.

# %%
car_company = df1.groupby("company")

# %%
toyota_details = car_company.get_group("toyota")

# %%
toyota_details
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# # Question 5: Count total cars per company

# %%
df1.company.value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mercedes-benz    4
# audi             4
# mitsubishi       4
# porsche          3
# jaguar           3
# honda            3
# chevrolet        3
# isuzu            3
# alfa-romero      3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
df1['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mercedes-benz    4
# audi             4
# mitsubishi       4
# porsche          3
# jaguar           3
# honda            3
# chevrolet        3
# isuzu            3
# alfa-romero      3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %% [markdown]
# # Question 6: Find each company’s Higesht price car

# %%
car_company = df1.groupby("company")

# %%
max_price_each_company = car_company.price.max()

# %%
max_price_each_company
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
max_price_each_company = car_company["price","company"].max()
# Out:
# c:\users\praz1\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
max_price_each_company
# Out:
#                  price        company
# company
# alfa-romero    16500.0    alfa-romero
# audi           18920.0           audi
# bmw            41315.0            bmw
# chevrolet       6575.0      chevrolet
# dodge           6377.0          dodge
# honda          12945.0          honda
# isuzu           6785.0          isuzu
# jaguar         36000.0         jaguar
# mazda          18344.0          mazda
# mercedes-benz  45400.0  mercedes-benz
# mitsubishi      8189.0     mitsubishi
# nissan         13499.0         nissan
# porsche        37028.0        porsche
# toyota         15750.0         toyota
# volkswagen      9995.0     volkswagen
# volvo          13415.0          volvo

# %% [markdown]
# # Question 7: Find the average mileage of each car making company.

# %%
car_company = df1.groupby("company")

# %%
avg_milage = car_company["company","average-mileage"].mean()
# Out:
# c:\users\praz1\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
avg_milage
# Out:
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %% [markdown]
# # Question 8: Sort all cars by Price column.

# %%
SortPrice = df1.sort_values(by=["price"],ascending = False)
SortPrice
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
# ..    ...            ...          ...         ...     ...         ...
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 22     31          isuzu        sedan        94.5   155.9         ohc
# 23     32          isuzu        sedan        94.5   155.9         ohc
# 47     63        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# ...

# %% [markdown]
# # Question 9: Concatenate two data frames using the following conditions
# # Create two data frames using the following two Dicts, Concatenate those two data frames and create a key for each data frame.
# # GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
# # japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
d3 = pandas.DataFrame.from_dict(GermanCars)

# %%
d3
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
d4 = pandas.DataFrame.from_dict(japaneseCars)

# %%
d4
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
cars = pandas.concat([d3,d4],keys = ["Germany","Japan"])
cars
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# # Question 10: Merge two data frames using the following condition
# # Create two data frames using the following two Dicts, Merge two data frames, and append the second data frame as a new column to the first data frame.
# # Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
# # car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
CarPrice = pandas.DataFrame.from_dict(Car_Price)

# %%
CarPrice
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
CarHP = pandas.DataFrame.from_dict(car_Horsepower)

# %%
CarHP
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
CarDF = pandas.merge(CarPrice, CarHP ,on = "Company")
CarDF
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
